# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from matplotlib.pyplot import xticks

# %%
df = pd.DataFrame(pd.read_csv("CarPrice.csv"))

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder,OrdinalEncoder

# %%
fuel=["diesel","gas"]

# %%
enc=OrdinalEncoder(categories=[fuel])
df["fueltype"]=enc.fit_transform(df[["fueltype"]])
df
# Out:
#      car_ID  symboling                   CarName  fueltype aspiration  \
# 0         1          3        alfa-romero giulia       1.0        std
# 1         2          3       alfa-romero stelvio       1.0        std
# 2         3          1  alfa-romero Quadrifoglio       1.0        std
# 3         4          2               audi 100 ls       1.0        std
# 4         5          2                audi 100ls       1.0        std
# ..      ...        ...                       ...       ...        ...
# 200     201         -1           volvo 145e (sw)       1.0        std
# 201     202         -1               volvo 144ea       1.0      turbo
# 202     203         -1               volvo 244dl       1.0        std
# 203     204         -1                 volvo 246       0.0      turbo
# 204     205         -1               volvo 264gl       1.0      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
aspir=["std","turbo"]
enc1=OrdinalEncoder(categories=[aspir])
df["aspiration"]=enc1.fit_transform(df[["aspiration"]])
df
# Out:
#      car_ID  symboling                   CarName  fueltype  aspiration  \
# 0         1          3        alfa-romero giulia       1.0         0.0
# 1         2          3       alfa-romero stelvio       1.0         0.0
# 2         3          1  alfa-romero Quadrifoglio       1.0         0.0
# 3         4          2               audi 100 ls       1.0         0.0
# 4         5          2                audi 100ls       1.0         0.0
# ..      ...        ...                       ...       ...         ...
# 200     201         -1           volvo 145e (sw)       1.0         0.0
# 201     202         -1               volvo 144ea       1.0         1.0
# 202     203         -1               volvo 244dl       1.0         0.0
# 203     204         -1                 volvo 246       0.0         1.0
# 204     205         -1               volvo 264gl       1.0         1.0
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
df.replace("four",4,inplace=True)

# %%
df.replace("two",2,inplace=True)

# %%
df
# Out:
#      car_ID  symboling                   CarName  fueltype  aspiration  \
# 0         1          3        alfa-romero giulia       1.0         0.0
# 1         2          3       alfa-romero stelvio       1.0         0.0
# 2         3          1  alfa-romero Quadrifoglio       1.0         0.0
# 3         4          2               audi 100 ls       1.0         0.0
# 4         5          2                audi 100ls       1.0         0.0
# ..      ...        ...                       ...       ...         ...
# 200     201         -1           volvo 145e (sw)       1.0         0.0
# 201     202         -1               volvo 144ea       1.0         1.0
# 202     203         -1               volvo 244dl       1.0         0.0
# 203     204         -1                 volvo 246       0.0         1.0
# 204     205         -1               volvo 264gl       1.0         1.0
#
#      doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
engineloc=["front","rear"]
enc2=OrdinalEncoder(categories=[engineloc])
df["enginelocation"]=enc2.fit_transform(df[["enginelocation"]])
df
# Out:
#      car_ID  symboling                   CarName  fueltype  aspiration  \
# 0         1          3        alfa-romero giulia       1.0         0.0
# 1         2          3       alfa-romero stelvio       1.0         0.0
# 2         3          1  alfa-romero Quadrifoglio       1.0         0.0
# 3         4          2               audi 100 ls       1.0         0.0
# 4         5          2                audi 100ls       1.0         0.0
# ..      ...        ...                       ...       ...         ...
# 200     201         -1           volvo 145e (sw)       1.0         0.0
# 201     202         -1               volvo 144ea       1.0         1.0
# 202     203         -1               volvo 244dl       1.0         0.0
# 203     204         -1                 volvo 246       0.0         1.0
# 204     205         -1               volvo 264gl       1.0         1.0
#
#      doornumber      carbody drivewheel  enginelocation  wheelbase  ...  \
# ...

# %%
enc3=OrdinalEncoder()
df["carbody"]=enc3.fit_transform(df[["carbody"]])
df
# Out:
#      car_ID  symboling                   CarName  fueltype  aspiration  \
# 0         1          3        alfa-romero giulia       1.0         0.0
# 1         2          3       alfa-romero stelvio       1.0         0.0
# 2         3          1  alfa-romero Quadrifoglio       1.0         0.0
# 3         4          2               audi 100 ls       1.0         0.0
# 4         5          2                audi 100ls       1.0         0.0
# ..      ...        ...                       ...       ...         ...
# 200     201         -1           volvo 145e (sw)       1.0         0.0
# 201     202         -1               volvo 144ea       1.0         1.0
# 202     203         -1               volvo 244dl       1.0         0.0
# 203     204         -1                 volvo 246       0.0         1.0
# 204     205         -1               volvo 264gl       1.0         1.0
#
#      doornumber  carbody drivewheel  enginelocation  wheelbase  ...  \
# ...

# %%
enc4=OrdinalEncoder()
df["drivewheel"]=enc4.fit_transform(df[["drivewheel"]])
df
# Out:
#      car_ID  symboling                   CarName  fueltype  aspiration  \
# 0         1          3        alfa-romero giulia       1.0         0.0
# 1         2          3       alfa-romero stelvio       1.0         0.0
# 2         3          1  alfa-romero Quadrifoglio       1.0         0.0
# 3         4          2               audi 100 ls       1.0         0.0
# 4         5          2                audi 100ls       1.0         0.0
# ..      ...        ...                       ...       ...         ...
# 200     201         -1           volvo 145e (sw)       1.0         0.0
# 201     202         -1               volvo 144ea       1.0         1.0
# 202     203         -1               volvo 244dl       1.0         0.0
# 203     204         -1                 volvo 246       0.0         1.0
# 204     205         -1               volvo 264gl       1.0         1.0
#
#      doornumber  carbody  drivewheel  enginelocation  wheelbase  ...  \
# ...

# %%
df["fuelsystem"]=enc4.fit_transform(df[["fuelsystem"]])
df
# Out:
#      car_ID  symboling                   CarName  fueltype  aspiration  \
# 0         1          3        alfa-romero giulia       1.0         0.0
# 1         2          3       alfa-romero stelvio       1.0         0.0
# 2         3          1  alfa-romero Quadrifoglio       1.0         0.0
# 3         4          2               audi 100 ls       1.0         0.0
# 4         5          2                audi 100ls       1.0         0.0
# ..      ...        ...                       ...       ...         ...
# 200     201         -1           volvo 145e (sw)       1.0         0.0
# 201     202         -1               volvo 144ea       1.0         1.0
# 202     203         -1               volvo 244dl       1.0         0.0
# 203     204         -1                 volvo 246       0.0         1.0
# 204     205         -1               volvo 264gl       1.0         1.0
#
#      doornumber  carbody  drivewheel  enginelocation  wheelbase  ...  \
# ...

# %%
df["enginetype"]=enc4.fit_transform(df[["enginetype"]])
df
# Out:
#      car_ID  symboling                   CarName  fueltype  aspiration  \
# 0         1          3        alfa-romero giulia       1.0         0.0
# 1         2          3       alfa-romero stelvio       1.0         0.0
# 2         3          1  alfa-romero Quadrifoglio       1.0         0.0
# 3         4          2               audi 100 ls       1.0         0.0
# 4         5          2                audi 100ls       1.0         0.0
# ..      ...        ...                       ...       ...         ...
# 200     201         -1           volvo 145e (sw)       1.0         0.0
# 201     202         -1               volvo 144ea       1.0         1.0
# 202     203         -1               volvo 244dl       1.0         0.0
# 203     204         -1                 volvo 246       0.0         1.0
# 204     205         -1               volvo 264gl       1.0         1.0
#
#      doornumber  carbody  drivewheel  enginelocation  wheelbase  ...  \
# ...

# %%
df.replace("two",2,inplace=True)
df.replace("three",3,inplace=True)
df.replace("four",4,inplace=True)
df.replace("five",5,inplace=True)
df.replace("six",6,inplace=True)
df.replace("eight",8,inplace=True)
df.replace("twelve",12,inplace=True)

# %%
df.describe()
# Out:
#            car_ID   symboling    fueltype  aspiration  doornumber     carbody  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146    0.902439    0.180488    3.121951    2.614634
# std     59.322565    1.245307    0.297446    0.385535    0.994966    0.859081
# min      1.000000   -2.000000    0.000000    0.000000    2.000000    0.000000
# 25%     52.000000    0.000000    1.000000    0.000000    2.000000    2.000000
# 50%    103.000000    1.000000    1.000000    0.000000    4.000000    3.000000
# 75%    154.000000    2.000000    1.000000    0.000000    4.000000    3.000000
# max    205.000000    3.000000    1.000000    1.000000    4.000000    4.000000
#
#        drivewheel  enginelocation   wheelbase   carlength  ...  enginesize  \
# count  205.000000      205.000000  205.000000  205.000000  ...  205.000000
# mean     1.326829        0.014634   98.756585  174.049268  ...  126.907317
# ...

# %%
df['brand'] = df.CarName.str.split(' ').str.get(0).str.upper()

# %%
len(set(df.brand.values))
# Out:
# 27

# %%
fig, ax = plt.subplots(figsize = (15,5))
plt1 = sns.countplot(df['brand'], order=pd.value_counts(df['brand']).index,)
plt1.set(xlabel = 'Brand', ylabel= 'Count of Cars')
xticks(rotation = 90)
plt.show()
# Out:
# C:\Users\Rithigasri\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['brand'] = df['brand'].replace(['VW', 'VOKSWAGEN'], 'VOLKSWAGEN')
df['brand'] = df['brand'].replace(['MAXDA'], 'MAZDA')
df['brand'] = df['brand'].replace(['PORCSHCE'], 'PORSCHE')
df['brand'] = df['brand'].replace(['TOYOUTA'], 'TOYOTA')

# %%
fig, ax = plt.subplots(figsize = (15,5))
plt1 = sns.countplot(df['brand'], order=pd.value_counts(df['brand']).index,)
plt1.set(xlabel = 'Brand', ylabel= 'Count of Cars')
xticks(rotation = 90)
plt.show()
# Out:
# C:\Users\Rithigasri\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.brand.describe()
# Out:
# count        205
# unique        22
# top       TOYOTA
# freq          32
# Name: brand, dtype: object

# %%
df["brand"]=enc3.fit_transform(df[["brand"]])
df
# Out:
#      car_ID  symboling                   CarName  fueltype  aspiration  \
# 0         1          3        alfa-romero giulia       1.0         0.0
# 1         2          3       alfa-romero stelvio       1.0         0.0
# 2         3          1  alfa-romero Quadrifoglio       1.0         0.0
# 3         4          2               audi 100 ls       1.0         0.0
# 4         5          2                audi 100ls       1.0         0.0
# ..      ...        ...                       ...       ...         ...
# 200     201         -1           volvo 145e (sw)       1.0         0.0
# 201     202         -1               volvo 144ea       1.0         1.0
# 202     203         -1               volvo 244dl       1.0         0.0
# 203     204         -1                 volvo 246       0.0         1.0
# 204     205         -1               volvo 264gl       1.0         1.0
#
#      doornumber  carbody  drivewheel  enginelocation  wheelbase  ...  \
# ...

# %%
first_column = df.pop('brand')

df.insert(0, 'brand', first_column)

# %%
df.drop(df[["CarName"]],axis=1,inplace=True)

# %%
df
# Out:
#      brand  car_ID  symboling  fueltype  aspiration  doornumber  carbody  \
# 0      0.0       1          3       1.0         0.0           2      0.0
# 1      0.0       2          3       1.0         0.0           2      0.0
# 2      0.0       3          1       1.0         0.0           2      2.0
# 3      1.0       4          2       1.0         0.0           4      3.0
# 4      1.0       5          2       1.0         0.0           4      3.0
# ..     ...     ...        ...       ...         ...         ...      ...
# 200   21.0     201         -1       1.0         0.0           4      3.0
# 201   21.0     202         -1       1.0         1.0           4      3.0
# 202   21.0     203         -1       1.0         0.0           4      3.0
# 203   21.0     204         -1       0.0         1.0           4      3.0
# 204   21.0     205         -1       1.0         1.0           4      3.0
#
#      drivewheel  enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# ...

# %%
#Filter Methods

# %%
X=df.drop("price",1)
y=df["price"]

# %%
X.shape
# Out:
# (205, 25)

# %%
df.drop("symboling",1,inplace=True)

# %%
from sklearn.feature_selection import VarianceThreshold

# %%
#1.Variance Threshold
selector = VarianceThreshold()
selector.fit_transform(X)
# Out:
# array([[ 0.00e+00,  1.00e+00,  3.00e+00, ...,  5.00e+03,  2.10e+01,
#          2.70e+01],
#        [ 0.00e+00,  2.00e+00,  3.00e+00, ...,  5.00e+03,  2.10e+01,
#          2.70e+01],
#        [ 0.00e+00,  3.00e+00,  1.00e+00, ...,  5.00e+03,  1.90e+01,
#          2.60e+01],
#        ...,
#        [ 2.10e+01,  2.03e+02, -1.00e+00, ...,  5.50e+03,  1.80e+01,
#          2.30e+01],
#        [ 2.10e+01,  2.04e+02, -1.00e+00, ...,  4.80e+03,  2.60e+01,
#          2.70e+01],
#        [ 2.10e+01,  2.05e+02, -1.00e+00, ...,  5.40e+03,  1.90e+01,
#          2.50e+01]])

# %%
#2.Information gain/Mutual Information
from sklearn.feature_selection import mutual_info_regression
mi = mutual_info_regression(X, y);

# %%
mi = pd.Series(mi)
mi.index = X.columns
mi.sort_values(ascending=False)
mi.sort_values(ascending=False).plot.bar(figsize=(10, 4))
# Out:
# <AxesSubplot:>

# %%
#3.SelectKBest Model
from sklearn.feature_selection import SelectKBest, f_classif,chi2
bestfeatures = SelectKBest(score_func=f_classif, k=3)
X_trim = bestfeatures.fit_transform(X,y)
print(bestfeatures.scores_)
print(bestfeatures.pvalues_)
print(X_trim.shape)
# Out:
# [ 2.07274187  1.57611042  1.90928905  1.45096004  5.0760768   2.06331085
#   3.11821484  5.28531396         inf 10.27215716 17.04739001 18.60420579
#   2.67409629 36.89334129  1.20258779 10.05625324 40.73817399  5.32772344
#   2.13504606  2.42596558  1.40026486 17.35176432  5.3166754  10.45495331
#   7.98691047]
# [4.66117863e-02 1.46785663e-01 6.74477261e-02 1.97350182e-01
#  2.83399529e-04 4.76035417e-02 5.62972779e-03 2.17412892e-04
#  0.00000000e+00 2.13062617e-06 4.97069627e-08 2.56495305e-08
#  1.31037295e-02 1.31537614e-10 3.51298823e-01 2.48558336e-06
#  6.06953872e-11 2.06250159e-04 4.05941556e-02 2.17298953e-02
#  2.22406009e-01 4.34854984e-08 2.09094980e-04 1.87426328e-06
#  1.29200432e-05]
# (205, 3)
# C:\Users\Rithigasri\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: divide by zero encountered in true_divide
#   f = msb / msw

# %%
#4.Correlation Coefficient

# %%
cor=df.corr()

# %%
sns.heatmap(cor,annot=True)
# Out:
# <AxesSubplot:>

# %%
#5.Mean Absolute Difference

# %%
mad=np.sum(np.abs(X-np.mean(X,axis=0)),axis=0)/X.shape[0]
plt.bar(np.arange(X.shape[1]),mad,color='teal')
# Out:
# <BarContainer object of 25 artists>

# %%
#Wrapper method

# %%
#1.Forward feature selection

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.linear_model import LinearRegression

# %%
sfs = SFS(LinearRegression(),
          k_features=15,
          forward=True,
          floating=False,
          scoring = 'r2',
          cv = 0)
sfs.fit(X, y)
sfs.k_feature_names_
# Out:
# ('brand',
#  'car_ID',
#  'fueltype',
#  'drivewheel',
#  'enginelocation',
#  'wheelbase',
#  'carwidth',
#  'curbweight',
#  'cylindernumber',
#  'enginesize',
#  'boreratio',
#  'stroke',
#  'compressionratio',
#  'horsepower',
#  'peakrpm')

# %%
#2.Backward feature elimination

# %%
sbs = SFS(LinearRegression(),
         k_features=15,
         forward=False,
         floating=False,
         cv=0)
sbs.fit(X, y)
sbs.k_feature_names_
# Out:
# ('brand',
#  'car_ID',
#  'fueltype',
#  'enginelocation',
#  'wheelbase',
#  'carwidth',
#  'carheight',
#  'curbweight',
#  'cylindernumber',
#  'enginesize',
#  'boreratio',
#  'stroke',
#  'compressionratio',
#  'horsepower',
#  'peakrpm')

# %%
#3.Bi-directional elimination

# %%
sffs = SFS(LinearRegression(),
         k_features=(3,15),
         forward=True,
         floating=True,
         cv=0)
sffs.fit(X, y)
sffs.k_feature_names_
# Out:
# ('brand',
#  'car_ID',
#  'fueltype',
#  'drivewheel',
#  'enginelocation',
#  'wheelbase',
#  'carwidth',
#  'curbweight',
#  'cylindernumber',
#  'enginesize',
#  'boreratio',
#  'stroke',
#  'compressionratio',
#  'horsepower',
#  'peakrpm')

# %%
#4.Recursive Feature Selection

# %%
from sklearn.feature_selection import RFE
lr=LinearRegression()

# %%
rfe=RFE(lr,n_features_to_select=7)
rfe.fit(X, y)
# Out:
# RFE(estimator=LinearRegression(), n_features_to_select=7)

# %%
print(X.shape, y.shape)
# Out:
# (205, 25) (205,)

# %%
rfe.transform(X)
# Out:
# array([[ 0.  ,  0.  ,  2.  , ..., 64.1 ,  4.  ,  3.47],
#        [ 0.  ,  0.  ,  2.  , ..., 64.1 ,  4.  ,  3.47],
#        [ 0.  ,  2.  ,  2.  , ..., 65.5 ,  6.  ,  2.68],
#        ...,
#        [ 0.  ,  3.  ,  2.  , ..., 68.9 ,  6.  ,  3.58],
#        [ 1.  ,  3.  ,  2.  , ..., 68.9 ,  6.  ,  3.01],
#        [ 1.  ,  3.  ,  2.  , ..., 68.9 ,  4.  ,  3.78]])

# %%
rfe.get_params(deep=True)
# Out:
# {'estimator__copy_X': True,
#  'estimator__fit_intercept': True,
#  'estimator__n_jobs': None,
#  'estimator__normalize': False,
#  'estimator__positive': False,
#  'estimator': LinearRegression(),
#  'importance_getter': 'auto',
#  'n_features_to_select': 7,
#  'step': 1,
#  'verbose': 0}

# %%
rfe.support_
# Out:
# array([False, False, False, False,  True, False,  True,  True,  True,
#        False, False,  True, False, False, False,  True, False, False,
#         True, False, False, False, False, False, False])

# %%
rfe.ranking_
# Out:
# array([ 5, 12,  9,  6,  1, 13,  1,  1,  1, 14, 16,  1,  3, 18, 17,  1, 11,
#         4,  1,  2,  8, 15, 19,  7, 10])

# %%
#EMBEDDED METHOD

# %%
#1.Random Forest Importance

# %%
lab = preprocessing.LabelEncoder()
y_transformed = lab.fit_transform(y)
print(y_transformed)
# Out:
# [118 137 137 123 148 128 150 159 169 151 136 145 163 164 170 174 187 184
#    1  11  17   7  13  49  10  20  41  63  67 114  14  25   5  16  32  34
#   34  47  70  65  89 113  90  22  66  66  96 177 182 183   2   8  23  21
#   37  95 104 120 131  65  61  91  88  93  98 154 155 171 173 172 176 180
#  181 186 188 138   4   9  19  42  81  62 110 126 125  28  55  73  73   6
#   30  18  24  36  35  46  39  52  58  69  78 119 124 119 147 162 156 106
#  115 109 122 130 144 142 146 141 152 153   7  49  10  20  41  67 111 166
#  178 179 185 175  74  80 105 107 127 129 153 158   0  29  40  31  44  82
#   71 100  38  87  53 103   3  12  15  26  48  64  27  33  48  45  43  59
#   72  54  57  75  77  60  79  85  97 101 149  68  92  84  94  99 140 135
#  132 133  44  50  51  56  61  76  86 102  83 116 121 108 112 117 134 139
#  157 160 143 161 165 167 168]

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier().fit(X,y_transformed)
importances=model.feature_importances_

# %%
final_df=pd.DataFrame({"Features":pd.DataFrame(X).columns,"Importances":importances})
final_df.set_index("Importances")
final_df=final_df.sort_values("Importances")

# %%
final_df.plot.bar(color="teal")
# Out:
# <AxesSubplot:>
